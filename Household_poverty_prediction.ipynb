# %%
# !pip install feature_engine
# Out:
# ...
#      |████████████████████████████████| 184kB 5.0MB/s
# ...
#      |████████████████████████████████| 9.5MB 18.0MB/s
# ...
#   Found existing installation: statsmodels 0.10.2
#     Uninstalling statsmodels-0.10.2:
#       Successfully uninstalled statsmodels-0.10.2
# ...

# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import KBinsDiscretizer
# from feature_engine.discretisers import DecisionTreeDiscretiser
# from feature_engine import discretisers as dsc
import matplotlib.pyplot as plt
from sklearn.model_selection import RandomizedSearchCV


train=pd.read_csv('train.csv')
train.head()

y_train=train['poor']
y_train
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 7377    False
# 7378    False
# 7379     True
# 7380    False
# 7381    False
# Name: poor, Length: 7382, dtype: bool

# %%
x_train=train.drop(columns=['poor',train.columns[0]])
x_train
# Out:
#          id wBXbHZmp SlDKnCuu KAJOWiiw  ... HGPWuGlV GDUPaBQs WuwrCsIY AlDbXTlZ
# 0     66721    JhtDR    GUusz    TuovO  ...    vkbkA    qQxrL    AITFl    cecIq
# 1     75174    JhtDR    GUusz    TuovO  ...    vkbkA    qQxrL    AITFl    cecIq
# 2     62573    JhtDR    GUusz    TuovO  ...    vkbkA    qQxrL    AITFl    cecIq
# 3     50733    JhtDR    GUusz    TuovO  ...    vkbkA    qQxrL    AITFl    cecIq
# 4     71295    JhtDR    GUusz    TuovO  ...    vkbkA    qQxrL    AITFl    aQeIm
# ...     ...      ...      ...      ...  ...      ...      ...      ...      ...
# 7377  72085    JhtDR    GUusz    BIZns  ...    vkbkA    qQxrL    AITFl    cecIq
# 7378  73479    JhtDR    GUusz    TuovO  ...    vkbkA    qQxrL    AITFl    aQeIm
# 7379  17275    JhtDR    GUusz    TuovO  ...    vkbkA    qQxrL    AITFl    aQeIm
# 7380  54917    JhtDR    GUusz    TuovO  ...    vkbkA    qQxrL    AITFl    cecIq
# 7381  64745    DkQlr    GUusz    BIZns  ...    vkbkA    qQxrL    GAZGl    cecIq
#
# ...

# %%
le = LabelEncoder()

for col in x_train.columns:
  if(train[col].dtype == np.dtype('O')):
    x_train[col] = le.fit_transform(x_train[col])
  
# x_train=pd.get_dummies(train,columns=str_col)
#df_encoded = x_train[str_col].apply(le.fit_transform)

#x_train=x_train.drop(columns=['poor','id',x_train.columns[0]])


x_train
# Out:
#          id  wBXbHZmp  SlDKnCuu  ...  GDUPaBQs  WuwrCsIY  AlDbXTlZ
# 0     66721         1         0  ...         1         0         1
# 1     75174         1         0  ...         1         0         1
# 2     62573         1         0  ...         1         0         1
# 3     50733         1         0  ...         1         0         1
# 4     71295         1         0  ...         1         0         0
# ...     ...       ...       ...  ...       ...       ...       ...
# 7377  72085         1         0  ...         1         0         1
# 7378  73479         1         0  ...         1         0         0
# 7379  17275         1         0  ...         1         0         0
# 7380  54917         1         0  ...         1         0         1
# 7381  64745         0         0  ...         1         1         1
#
# [7382 rows x 334 columns]

# %%
x_train.corr()
# Out:
#                 id  wBXbHZmp  SlDKnCuu  ...  GDUPaBQs  WuwrCsIY  AlDbXTlZ
# id        1.000000 -0.018834 -0.013684  ... -0.015472 -0.009279  0.002520
# wBXbHZmp -0.018834  1.000000  0.003341  ...  0.171089  0.009973  0.048966
# SlDKnCuu -0.013684  0.003341  1.000000  ... -0.031613  0.016315  0.003631
# KAJOWiiw -0.000677  0.054865 -0.011024  ...  0.035410  0.018466  0.037209
# DsKacCdL -0.015912  0.340636  0.016795  ...  0.126037  0.034385  0.181431
# ...            ...       ...       ...  ...       ...       ...       ...
# JCDeZBXq -0.010988  0.140845  0.040082  ...  0.059391 -0.035854  0.172180
# HGPWuGlV  0.002526  0.008837 -0.043975  ... -0.009876  0.001555  0.037261
# GDUPaBQs -0.015472  0.171089 -0.031613  ...  1.000000 -0.017355  0.019936
# WuwrCsIY -0.009279  0.009973  0.016315  ... -0.017355  1.000000 -0.006460
# AlDbXTlZ  0.002520  0.048966  0.003631  ...  0.019936 -0.006460  1.000000
#
# [334 rows x 334 columns]

# %%
col_normalize = ['nEsgxvAq', 'OMtioXZZ', 'YFMZwKrU', 'TiwRslOh']
x = x_train[col_normalize].values
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df_temp = pd.DataFrame(x_scaled, columns=col_normalize, index = x_train.index)
x_train[col_normalize] = df_temp
x_train
# Out:
#          id  wBXbHZmp  SlDKnCuu  ...  GDUPaBQs  WuwrCsIY  AlDbXTlZ
# 0     66721         1         0  ...         1         0         1
# 1     75174         1         0  ...         1         0         1
# 2     62573         1         0  ...         1         0         1
# 3     50733         1         0  ...         1         0         1
# 4     71295         1         0  ...         1         0         0
# ...     ...       ...       ...  ...       ...       ...       ...
# 7377  72085         1         0  ...         1         0         1
# 7378  73479         1         0  ...         1         0         0
# 7379  17275         1         0  ...         1         0         0
# 7380  54917         1         0  ...         1         0         1
# 7381  64745         0         0  ...         1         1         1
#
# [7382 rows x 334 columns]

# %%
# x_train=np.array(x_train)
# x_train

# y_train=np.array(y_train)
# y_train

# %%
# n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)]
# max_features = ['auto', 'sqrt']
# max_depth = [int(x) for x in np.linspace(10, 110, num = 11)]
# max_depth.append(None)
# min_samples_split = [2, 5, 10]
# min_samples_leaf = [1, 2, 4]
# bootstrap = [True, False]
# random_grid = {'n_estimators': n_estimators,
#                'max_features': max_features,
#                'max_depth': max_depth,
#                'min_samples_split': min_samples_split,
#                'min_samples_leaf': min_samples_leaf,
#                'bootstrap': bootstrap}

# %%
# # param_grid = {
# #     'bootstrap': [True],
# #     'max_depth': [80, 90, 100, 110],
# #     'max_features': [2, 3],
# #     'min_samples_leaf': [3, 4, 5],
# #     'min_samples_split': [8, 10, 12],
# #     'n_estimators': [100, 200, 300, 1000]
# # }

# rf = RandomForestClassifier()

# rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid, n_iter = 100, cv = 3, verbose=2, random_state=42, n_jobs = -1)
# # grid_search = GridSearchCV(estimator = rf, param_grid = param_grid, 
# #                           cv = 3, n_jobs = -1, verbose = 2)

# rf_random.fit(x_train, y_train)

# %%
rf = RandomForestClassifier()
rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
importances = pd.DataFrame({'feature':x_train.columns,'importance':np.round(rf.feature_importances_,3)})
importances = importances.sort_values('importance',ascending=False)
importances.head(100)
imp_train=pd.DataFrame({})
i=0

  
for row in importances['feature']:
  for col in x_train.columns:
   if row==col:
    imp_train[col]=x_train[col]
    i=i+1
  if i==101:
    break

imp_train=imp_train.drop(columns=['id'])
imp_train
# Out:
#       TiwRslOh  wEbmsuJO  IZFarbPw  ...  JCDeZBXq  CsGvKKBJ  kZVpcgJL
# 0     0.529412         0         1  ...         1         0         0
# 1     0.764706         1         0  ...         0         0         0
# 2     0.882353         0         1  ...         0         0         0
# 3     0.705882         1         0  ...         1         0         0
# 4     0.882353         0         1  ...         1         0         0
# ...        ...       ...       ...  ...       ...       ...       ...
# 7377  0.764706         0         1  ...         1         0         0
# 7378  0.588235         0         1  ...         1         0         1
# 7379  0.529412         1         0  ...         1         0         0
# 7380  1.000000         0         1  ...         0         0         0
# 7381  0.823529         0         0  ...         1         1         0
#
# [7382 rows x 100 columns]

# %%
rf.fit(imp_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
test=pd.read_csv('test.csv')

x_test=test.drop(columns=['id',test.columns[0]])

str_col=[]
for col in test.columns:
  if(test[col].dtype == np.dtype('O')):
    x_test[col] = le.fit_transform(x_test[col])
    
#x_test=pd.get_dummies(test,columns=str_col)

x_test

# test.shape
# Out:
#      wBXbHZmp  SlDKnCuu  KAJOWiiw  ...  GDUPaBQs  WuwrCsIY  AlDbXTlZ
# 0           1         0         0  ...         1         0         1
# 1           1         1         1  ...         1         0         1
# 2           1         0         1  ...         1         0         1
# 3           1         0         1  ...         1         0         1
# 4           1         0         0  ...         1         0         0
# ..        ...       ...       ...  ...       ...       ...       ...
# 816         1         0         0  ...         1         0         1
# 817         1         1         0  ...         1         0         1
# 818         1         0         1  ...         1         0         1
# 819         1         0         0  ...         1         1         1
# 820         1         0         0  ...         1         0         0
#
# [821 rows x 333 columns]

# %%
col_normalize = ['nEsgxvAq', 'OMtioXZZ', 'YFMZwKrU', 'TiwRslOh']
x = x_test[col_normalize].values
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df_temp = pd.DataFrame(x_scaled, columns=col_normalize, index = x_test.index)
x_test[col_normalize] = df_temp
x_test
# Out:
#      wBXbHZmp  SlDKnCuu  KAJOWiiw  ...  GDUPaBQs  WuwrCsIY  AlDbXTlZ
# 0           1         0         0  ...         1         0         1
# 1           1         1         1  ...         1         0         1
# 2           1         0         1  ...         1         0         1
# 3           1         0         1  ...         1         0         1
# 4           1         0         0  ...         1         0         0
# ..        ...       ...       ...  ...       ...       ...       ...
# 816         1         0         0  ...         1         0         1
# 817         1         1         0  ...         1         0         1
# 818         1         0         1  ...         1         0         1
# 819         1         0         0  ...         1         1         1
# 820         1         0         0  ...         1         0         0
#
# [821 rows x 333 columns]

# %%
imp_test=pd.DataFrame({})

i=0
for row in importances['feature']:
  for col in x_test.columns:
   if row==col:
    imp_test[col]=x_test[col]
    i=i+1
  if i==100:
    break

imp_test
# Out:
#      TiwRslOh  wEbmsuJO  IZFarbPw  ...  JCDeZBXq  CsGvKKBJ  kZVpcgJL
# 0      0.5625         1         0  ...         1         0         0
# 1      0.9375         1         0  ...         1         1         0
# 2      0.6250         0         0  ...         1         0         1
# 3      0.6875         1         0  ...         1         0         0
# 4      0.5625         0         0  ...         1         0         0
# ..        ...       ...       ...  ...       ...       ...       ...
# 816    1.0000         0         1  ...         1         1         0
# 817    0.4375         1         0  ...         1         0         1
# 818    0.8125         0         0  ...         1         0         0
# 819    0.9375         1         0  ...         1         0         0
# 820    0.8750         1         1  ...         0         0         0
#
# [821 rows x 100 columns]

# %%
# x_test=np.array(x_test)
y_pred=rf.predict(imp_test)
y_pred
# Out:
# array([ True, False, False,  True, False, False,  True, False, False,
#         True, False, False, False, False, False,  True, False, False,
#         True, False, False,  True, False, False,  True, False, False,
#         True, False, False, False, False,  True, False, False,  True,
#        False, False, False, False, False, False, False,  True, False,
#        False,  True, False, False, False,  True,  True, False, False,
#        False, False, False, False,  True,  True, False, False,  True,
#        False,  True,  True,  True,  True, False, False, False, False,
#         True, False, False, False,  True, False,  True, False,  True,
#        False, False, False, False, False, False, False,  True, False,
#        False,  True, False, False,  True, False, False, False, False,
#        False, False,  True, False,  True, False, False,  True, False,
#        False, False, False, False, False, False,  True,  True, False,
# ...

# %%
y_pred=pd.DataFrame(y_pred)
y_pred.insert(0,'id',id,True)
y_pred.to_csv('pred.csv', index=False)
